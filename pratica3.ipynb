# %% [markdown]
# <a href="https://colab.research.google.com/github/LPATROCINIO1969/deeplearning/blob/main/pratica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2    # importa biblioteca OpenCV 
import numpy as np  # importa biblioteca para trabalhar com matrizes
import requests 
from PIL import Image   # importa biblioteca de imagem
from io import BytesIO  # importa biblioteca de io
from google.colab.patches import cv2_imshow # importa módulo para imprimir imagem

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
response = requests.get('https://static.educalingo.com/img/en/800/batrachia.jpg')
img = Image.open(BytesIO(response.content))
img = np.array(img)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x527 at 0x7FFBB10B0BD0>

# %%
# Cria o objeto de data augmentation
aug=ImageDataGenerator(height_shift_range=0.1,)
